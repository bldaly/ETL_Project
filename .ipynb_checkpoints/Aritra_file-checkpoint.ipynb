# %%
import requests
import json
import pandas as pd

from itertools import islice

# Google API Key
from config import gkey

# %%
chicago_df = pd.read_csv("updated_inspection.csv")
chicago_df.head()
# Out:
#    Unnamed: 0  Inspection ID                  DBA Name Facility Type  \
# 0           0        2268564            PIZZERIA AROMA    Restaurant
# 1           1        2268560            PIZZERIA AROMA    Restaurant
# 2           3        2268527                  CAFECITO    Restaurant
# 3           4        2268526  JOHNSON'S REAL ICE CREAM    Restaurant
# 4           5        2268524    TONY'S KITCHEN #2 INC.    Restaurant
#
#               Risk                    Address     City State      Zip  \
# 0    Risk 1 (High)           5350 N BROADWAY   CHICAGO    IL  60640.0
# 1    Risk 1 (High)           5350 N BROADWAY   CHICAGO    IL  60640.0
# 2    Risk 1 (High)  401-403 W FULLERTON PKWY   CHICAGO    IL  60614.0
# 3  Risk 2 (Medium)           2951 N BROADWAY   CHICAGO    IL  60657.0
# 4    Risk 1 (High)        6325 S CENTRAL AVE   CHICAGO    IL  60638.0
#
#        Inspection Date             Results   Latitude  Longitude
# 0  2019-02-26T00:00:00                Fail  41.979651 -87.660106
# 1  2019-02-26T00:00:00                Fail  41.979651 -87.660106
# 2  2019-02-26T00:00:00  Pass w/ Conditions  41.925501 -87.639179
# 3  2019-02-26T00:00:00  Pass w/ Conditions  41.936415 -87.644128
# 4  2019-02-26T00:00:00  Pass w/ Conditions  41.777201 -87.761542

# %%
target_type = "restaurant"
chicago_coords = "41.881832,-87.623177"
radius = 10000

# rewrite params dict
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
    "location": chicago_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

print("Restaurants in Chicago, IL")

# Run request
response = requests.get(base_url, params)

chicago_restaurant = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(chicago_restaurant, indent=4, sort_keys=True))

restaurants = []
chicago_rest_df = pd.DataFrame()

for index,restaurant in islice(chicago_df.iterrows(), 0, 200):    
    restr_name = restaurant['DBA Name']

    # add keyword to params dict
    params['keyword'] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        chicago_rest_df.loc[index, "Latitude"] = results[0]["geometry"]["location"]["lat"]
        chicago_rest_df.loc[index, "Longitude"] = results[0]["geometry"]["location"]["lng"]
        chicago_rest_df.loc[index, "Ratings"] =  results[0]["rating"]
        print(f"Record found for Restaurant : {restr_name}")
    except(KeyError, IndexError):
        print("Record not Found")
# Out:
# Restaurants in Chicago, IL
# Retrieving Results for Index 0: PIZZERIA AROMA.
# Record not Found
# Retrieving Results for Index 1: PIZZERIA AROMA.
# Record not Found
# Retrieving Results for Index 2: CAFECITO.
# Retrieving Results for Index 3: JOHNSON'S REAL ICE CREAM.
# Record not Found
# Retrieving Results for Index 4: TONY'S KITCHEN #2 INC..
# Record not Found
# Retrieving Results for Index 5: EL SABOR POBLANO.
# Record not Found
# Retrieving Results for Index 6: BOOILL GALBI.
# Record not Found
# Retrieving Results for Index 7: THE GARAGE BAR AND SANDWICHES.
# Record not Found
# Retrieving Results for Index 8: RUKIYO'S.
# Record not Found
# Retrieving Results for Index 9: HOANH LONG RESTAURANT, INC..
# Record not Found
# Retrieving Results for Index 10: EL REY DE LA COSTA.
# Retrieving Results for Index 11: LATIN PATIO.
# Record not Found
# Retrieving Results for Index 12: IYANZE.
# Retrieving Results for Index 13: GIORDANO'S RESTAURANT.
# Retrieving Results for Index 14: LITTLE KITCHEN.
# Retrieving Results for Index 15: YVOLINA'S TAMALES+GROCERIES.
# Retrieving Results for Index 16: Mom's Old Recipe Mexican Restaurant.
# Record not Found
# Retrieving Results for Index 17: BANGKOK THAI CUISINE.
# Record not Found
# Retrieving Results for Index 18: ROSATI'S PIZZA.
# Retrieving Results for Index 19: BOBTAIL SODA FOUNTAIN.
# Retrieving Results for Index 20: DUNKIN  DONUTS.
# Retrieving Results for Index 21: BURRITO STATION.
# Retrieving Results for Index 22: TAQUERIA KAIROS.
# Record not Found
# Retrieving Results for Index 23: Churro Factory Inc.
# Retrieving Results for Index 24: Jubilee Coffee, Inc / DBA Dunkin' Donuts.
# Record not Found
# Retrieving Results for Index 25: JOHNSON'S REAL ICE CREAM.
# Record not Found
# Retrieving Results for Index 26: PACOS TACOS CHICAGO.
# Retrieving Results for Index 27: POPEYES CHICKEN.
# Retrieving Results for Index 28: YOUNG'S RESTAURANT.
# Retrieving Results for Index 29: SUBWAY.
# Retrieving Results for Index 30: ROAD RANGER #187.
# Record not Found
# Retrieving Results for Index 31: CHARCOAL GUACAMOLE INC..
# Record not Found
# Retrieving Results for Index 32: JERSEY MIKE'S SUBS.
# Retrieving Results for Index 33: ORIENTAL CHEF.
# Record not Found
# Retrieving Results for Index 34: T JOELS FAMILY RESTAURANT.
# Retrieving Results for Index 35: JENI'S ILLINOIS LLC.
# Record not Found
# Retrieving Results for Index 36: MCCORMICK PLACE - SOUTH BUILDING - SAVOR.
# Retrieving Results for Index 37: DAN'S BAKERY& EATERY.
# Record not Found
# Retrieving Results for Index 38: SUBWAY.
# Retrieving Results for Index 39: LITO'S EMPANADAS.
# Retrieving Results for Index 40: CAFE BONHOMME / BEATNIX BY THE RIVER.
# Retrieving Results for Index 41: CHICAGO WINGS & GYROS.
# Retrieving Results for Index 42: CAFE BONHOMME / BEATNIX BY THE RIVER.
# Retrieving Results for Index 43: S & G GRILL.
# Retrieving Results for Index 44: NORWOOD RESTAURANT.
# Record not Found
# Retrieving Results for Index 45: LOS OLIVO'S.
# Retrieving Results for Index 46: Subway.
# Retrieving Results for Index 47: MIN MIN CAFE.
# Retrieving Results for Index 48: KAM FUNG RESTAURANT.
# Retrieving Results for Index 49: PIZZA NOVA EXPRESS.
# Retrieving Results for Index 50: Chipotle Mexican Grill.
# Retrieving Results for Index 51: JERSEY MIKE'S SUBS.
# Retrieving Results for Index 52: WingStop.
# Retrieving Results for Index 53: MR V'S CARRYOUT.
# Record not Found
# Retrieving Results for Index 54: EL MICHOACANITO.
# Retrieving Results for Index 55: KEN'S.
# Record not Found
# Retrieving Results for Index 56: STAN'S CORNER INC.
# Record not Found
# Retrieving Results for Index 57: SABOR A CAFE RESTAURANT.
# Retrieving Results for Index 58: MAKOTO.
# Retrieving Results for Index 59: CAPT'N NEMO.
# Retrieving Results for Index 60: EL TACO SABROSO #1 INC.
# Record not Found
# Retrieving Results for Index 61: THE PIZZA CORNER.
# Record not Found
# Retrieving Results for Index 62: JEONG.
# Retrieving Results for Index 63: 1st HUNAN SPRING, INC.
# Record not Found
# Retrieving Results for Index 64: CAFE BONHOMME / BEATNIX BY THE RIVER.
# Retrieving Results for Index 65: AMERICANOS.
# Record not Found
# Retrieving Results for Index 66: MR. POLLO.
# Retrieving Results for Index 67: ROJO GUSANO.
# Retrieving Results for Index 68: JEONG.
# Retrieving Results for Index 69: EL TACO AZTECA.
# Retrieving Results for Index 70: THE GOLDEN VILLAGE.
# Retrieving Results for Index 71: CAFE BONHOMME / BEATNIX BY THE RIVER.
# Retrieving Results for Index 72: POPEYE'S #831.
# Retrieving Results for Index 73: ZIGGY'S SIDE DOOR PUB & DELI.
# Record not Found
# Retrieving Results for Index 74: LA TORTA CHILANGA.
# Record not Found
# Retrieving Results for Index 75: DUNKIN DONUTS.
# Retrieving Results for Index 76: FOUR MOON TAVERN.
# Record not Found
# Retrieving Results for Index 77: EL SAZON RESTAURANT.
# Retrieving Results for Index 78: ELLY'S PANCAKE HOUSE.
# Retrieving Results for Index 79: RESTAURANT MIRO'SS INC..
# Retrieving Results for Index 80: GUS'S WORLD FAMOUS FRIED CHICKEN.
# Retrieving Results for Index 81: PIZZA HUT # 35190.
# Retrieving Results for Index 82: GUS'S WORLD FAMOUS FRIED CHICKEN.
# Retrieving Results for Index 83: ARCHIES.
# Retrieving Results for Index 84: DUNKIN DONUTS.
# Retrieving Results for Index 85: VELOX COFFEE.
# Record not Found
# Retrieving Results for Index 86: ELLIOTT'S SEAFOOD AND CHOP HOUSE GRILL.
# Record not Found
# Retrieving Results for Index 87: POPEYE'S#835.
# Retrieving Results for Index 88: Delhi Darbar Kabob House.
# Record not Found
# Retrieving Results for Index 89: POPEYES.
# Retrieving Results for Index 90: BYRONS KITCHENS.
# Retrieving Results for Index 91: EAT AND RUN  NFP.
# Record not Found
# Retrieving Results for Index 92: JIBARITOS ON HARLEM.
# Record not Found
# Retrieving Results for Index 93: LUZZAT RESTAURANT INC..
# Record not Found
# Retrieving Results for Index 94: ALEX LA MICHOACANA.
# Record not Found
# Retrieving Results for Index 95: JIANG'S KITCHEN INC..
# Record not Found
# Retrieving Results for Index 96: ANTOJITOS PUEBLITA INC.
# Retrieving Results for Index 97: SUSHI WORLD.
# Record not Found
# Retrieving Results for Index 98: PEPES RESTAURANT.
# Retrieving Results for Index 99: ANNA PURANA FAST FOOD.
# Record not Found
# Retrieving Results for Index 100: GREAT SEA CHINESE RESTAURANT.
# Retrieving Results for Index 101: COLUTA'S PIZZA.
# Record not Found
# Retrieving Results for Index 102: GREAT SEA CHINESE RESTAURANT.
# Retrieving Results for Index 103: Tortuga's Cantina.
# Retrieving Results for Index 104: PANERA BREAD.
# Retrieving Results for Index 105: NORWOOD RESTAURANT.
# Record not Found
# Retrieving Results for Index 106: BACON & JAM.
# Record not Found
# Retrieving Results for Index 107: MC DONALDS.
# Retrieving Results for Index 108: DUNKIN DONUTS.
# Retrieving Results for Index 109: SIMI'S.
# Record not Found
# Retrieving Results for Index 110: TACO BELL.
# Retrieving Results for Index 111: QUIZNO'S SUB.
# Retrieving Results for Index 112: DENDEN RESTAURANT.
# Record not Found
# Retrieving Results for Index 113: CHOLIES PIZZERIA INC..
# Retrieving Results for Index 114: CHINESE CHEF'S KITCHEN, INC..
# Retrieving Results for Index 115: BOMBASTIC CAFE.
# Record not Found
# Retrieving Results for Index 116: SMALL CHEVAL.
# Retrieving Results for Index 117: FIESTA BURGER HEAVEN, INC..
# Record not Found
# Retrieving Results for Index 118: USMANIA RESTAURANT.
# Record not Found
# Retrieving Results for Index 119: SUBWAY.
# Retrieving Results for Index 120: TERRY'S.
# Record not Found
# Retrieving Results for Index 121: TONY'S BURRITO MEX, INC.
# Retrieving Results for Index 122: BOYA FOOD TRADING.
# Record not Found
# Retrieving Results for Index 123: CHILI'S GRILL & BAR.
# Retrieving Results for Index 124: MAYAN PALACE 2.
# Retrieving Results for Index 125: MAYAN PALACE 2.
# Retrieving Results for Index 126: NAF NAF GRILL.
# Retrieving Results for Index 127: LEADER BAR.
# Record not Found
# Retrieving Results for Index 128: WINGSTOP.
# Retrieving Results for Index 129: BENCHMARK HOSPITALITY OF CHICAGO, INC..
# Retrieving Results for Index 130: BENCHMARK HOSPITALITY OF CHICAGO, INC..
# Retrieving Results for Index 131: WINDY CITY BBQ.
# Retrieving Results for Index 132: WINDY CITY BBQ.
# Retrieving Results for Index 133: TORTERIA SAN LENCHITO INC..
# Retrieving Results for Index 134: Las Delicias De Puerto Rico.
# Record not Found
# Retrieving Results for Index 135: THE  VERANDA ON THORNDALE.
# Record not Found
# Retrieving Results for Index 136: TAQUERIA EL HEREDERO INC.
# Retrieving Results for Index 137: TAQUERIA EL HEREDERO INC.
# Retrieving Results for Index 138: LE COLONIAL.
# Retrieving Results for Index 139: ELEVEN CITY DINER.
# Retrieving Results for Index 140: DUNKIN DONUTS.
# Retrieving Results for Index 141: YOSHI'S CAFE.
# Record not Found
# Retrieving Results for Index 142: LE COLONIAL.
# Retrieving Results for Index 143: MARISCOS EL KORA, INC..
# Retrieving Results for Index 144: ANTEPRIMA.
# Record not Found
# Retrieving Results for Index 145: MARISCOS EL KORA, INC..
# Retrieving Results for Index 146: I.H.O.P..
# Retrieving Results for Index 147: LOU MALNATI'S PIZZERIA.

# %%
chicago_rest_df.head()
# Out:
#      Latitude  Longitude  Ratings
# 2   41.875810 -87.626449      4.6
# 10  41.879322 -87.668978      4.3
# 13  41.885130 -87.623761      4.4
# 15  41.858237 -87.647300      4.5
# 18  41.864247 -87.646698      3.3

# %%
chicago_rest_df.to_csv('updated_rating.csv')
